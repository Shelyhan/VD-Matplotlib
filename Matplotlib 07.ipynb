# %% [markdown]
# ![title](https://qph.fs.quoracdn.net/main-qimg-d13baac8e5fdf8e18954ac6d0bad09de)
#
# # #13: 3D Plotting
#
# - Membuat 3D plotting dengan Matplotlib

# %% [markdown]
# ## Import modules

# %% [markdown]
# - `%matplotlib inline` untuk memanggil magic comment. Fungsinya untuk meredirect hasil output dari matplotlib ke tampilan jupyer   notebook di halaman notebook yang sama
# - Fungsi `%matplotlib notebook` sama seperti `%matplotlib inline`, tetapi sewaktu mengaktifkan `%matplotlib notebook` ini kita bisa berinteraksi dengan 3D plotting yang kita hasilkan
# - Kode di bawah ini untuk memberi tahu berapa versi matplotlib dan numpy kalian

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ## 3D Axes

# %% [markdown]
# - Memanggil object 3D harus membangun sendiri object figure dan object axes

# %%
fig = plt.figure()             # membentuk object figure
ax = plt.axes(projection='3d') # membentuk object axes 3D

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## 3D Line Plot

# %% [markdown]
# - Tiga variabel di bawah akan di plotting pada area 3D di atas

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()             
ax = plt.axes(projection='3d')

ax.plot(x, y, z, color='red') # optional

ax.set(title='Contoh 3D Line Plot',
       xlabel='Sumbu X',
       ylabel='Sumbu Y',
       zlabel='Sumbu Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## 3D Scatter Plot

# %% [markdown]
# - Tiga variabel di bawah akan di plotting pada area 3D di atas dengan bentuk Scatter Plot

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()             
ax = plt.axes(projection='3d')

ax.scatter(x, y, z, color='green')

ax.set(title='Contoh 3D Scatter Plot',
       xlabel='Sumbu X',
       ylabel='Sumbu Y',
       zlabel='Sumbu Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # #14: Contour Plot
#
# - Membuat Contour Plot dengan Matplotlib

# %% [markdown]
# ## Import modules

# %% [markdown]
# - `%matplotlib inline` untuk memanggil magic comment. Fungsinya untuk meredirect hasil output dari matplotlib ke tampilan jupyer   notebook di halaman notebook yang sama
# - Kode di bawah ini untuk memberi tahu berapa versi matplotlib dan numpy kalian

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ## Sample dataset

# %% [markdown]
# - Fungsi `meshgrid()` untuk membentuk data area
# - Ada tiga variabel, yaitu x, y, dan z
# - Tiga variabel tersebut akan mempresentasikan koordinat

# %%
n = np.linspace(-3.0, 3.0, 100)

x, y = np.meshgrid(n, n) 
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# ## Contour Plot

# %% [markdown]
# - Contour plot merupakan visualisasi data yang bisa digunakan untuk memvisualisasikan data 3D ke dalam format 2D
# - Perbedaan warna akan mempresentasikan perbedaan nilai

# %%
plt.contour(x, y, z)
plt.colorbar()

plt.title('Contour Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# ## Filled Contour Plot

# %% [markdown]
# - Fungsi filled contour plot untuk memenuhi areanya dengan warna

# %%
plt.contourf(x, y, z)
plt.colorbar()

plt.title('Filled Contour Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# # #15: 3D Area Plotting
#
# - Membuat 3D Area Plotting dengan Matplotlib

# %% [markdown]
# ## Import Modules

# %% [markdown]
# - `%matplotlib inline` untuk memanggil magic comment. Fungsinya untuk meredirect hasil output dari matplotlib ke tampilan jupyer   notebook di halaman notebook yang sama
# - Fungsi `%matplotlib notebook` sama seperti `%matplotlib inline`, tetapi sewaktu mengaktifkan `%matplotlib notebook` ini kita bisa berinteraksi dengan 3D plotting yang kita hasilkan
# - Kode di bawah ini untuk memberi tahu berapa versi matplotlib dan numpy kalian

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ## Sample dataset

# %%
n = np.linspace(-3.0, 3.0, 100)

x, y = np.meshgrid(n, n) 
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# ## 3D Wireframe

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x, y, z, color='orange')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## 3D Surface Plot

# %% [markdown]
# - Fungsi `plot_surface` untuk membentuk 3D surface plot

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, color='skyblue')
# ax.plot_surface(x, y, z, cmap='viridis') # color map

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
